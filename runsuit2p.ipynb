# %%
import os, requests
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

import suite2p
# Figure Style settings for notebook.
import matplotlib as mpl
mpl.rcParams.update({
    'axes.spines.left': True,
    'axes.spines.bottom': True,
    'axes.spines.top': False,
    'axes.spines.right': False,
    'legend.frameon': False,
    'figure.subplot.wspace': .01,
    'figure.subplot.hspace': .01,
    'figure.figsize': (18, 13),
    'ytick.major.left': True,
})
jet = mpl.colormaps.get_cmap('jet')
jet.set_bad(color='k')

# %%
ops = suite2p.default_ops()
for key, value in ops.items():
    print(f"{key}")
    print(f"{key}: {value}")


db = {
    'data_path':['/home/rum/Desktop/suite2pJed/run_suite2p']  ,
}
print(db)
# Out:
# suite2p_version
# suite2p_version: 0.14.4
# look_one_level_down
# look_one_level_down: False
# fast_disk
# fast_disk: []
# delete_bin
# delete_bin: False
# mesoscan
# mesoscan: False
# bruker
# bruker: False
# bruker_bidirectional
# bruker_bidirectional: False
# h5py
# h5py: []
# h5py_key
# h5py_key: data
# nwb_file
# nwb_file:
# nwb_driver
# nwb_driver:
# nwb_series
# nwb_series:
# save_path0
# save_path0:
# save_folder
# save_folder: []
# subfolders
# subfolders: []
# move_bin
# move_bin: False
# nplanes
# nplanes: 1
# nchannels
# nchannels: 1
# functional_chan
# functional_chan: 1
# tau
# tau: 1.0
# fs
# fs: 10.0
# force_sktiff
# force_sktiff: False
# frames_include
# frames_include: -1
# multiplane_parallel
# multiplane_parallel: False
# ignore_flyback
# ignore_flyback: []
# preclassify
# preclassify: 0.0
# save_mat
# save_mat: False
# save_NWB
# save_NWB: False
# combined
# combined: True
# aspect
# aspect: 1.0
# do_bidiphase
# do_bidiphase: False
# bidiphase
# bidiphase: 0
# bidi_corrected
# bidi_corrected: False
# do_registration
# do_registration: True
# two_step_registration
# two_step_registration: False
# keep_movie_raw
# keep_movie_raw: False
# nimg_init
# nimg_init: 300
# batch_size
# batch_size: 500
# maxregshift
# maxregshift: 0.1
# align_by_chan
# align_by_chan: 1
# reg_tif
# reg_tif: False
# reg_tif_chan2
# reg_tif_chan2: False
# subpixel
# subpixel: 10
# smooth_sigma_time
# smooth_sigma_time: 0
# smooth_sigma
# smooth_sigma: 1.15
# th_badframes
# th_badframes: 1.0
# norm_frames
# norm_frames: True
# force_refImg
# force_refImg: False
# pad_fft
# pad_fft: False
# nonrigid
# nonrigid: True
# block_size
# block_size: [128, 128]
# snr_thresh
# snr_thresh: 1.2
# maxregshiftNR
# maxregshiftNR: 5
# 1Preg
# 1Preg: False
# spatial_hp_reg
# spatial_hp_reg: 42
# pre_smooth
# pre_smooth: 0
# spatial_taper
# spatial_taper: 40
# roidetect
# roidetect: True
# spikedetect
# spikedetect: True
# sparse_mode
# sparse_mode: True
# spatial_scale
# spatial_scale: 0
# connected
# connected: True
# nbinned
# nbinned: 5000
# max_iterations
# max_iterations: 20
# threshold_scaling
# threshold_scaling: 1.0
# max_overlap
# max_overlap: 0.75
# high_pass
# high_pass: 100
# spatial_hp_detect
# spatial_hp_detect: 25
# denoise
# denoise: False
# anatomical_only
# anatomical_only: 0
# diameter
# diameter: 0
# cellprob_threshold
# cellprob_threshold: 0.0
# flow_threshold
# flow_threshold: 1.5
# spatial_hp_cp
# spatial_hp_cp: 0
# pretrained_model
# pretrained_model: cyto
# soma_crop
# soma_crop: True
# neuropil_extract
# neuropil_extract: True
# inner_neuropil_radius
# inner_neuropil_radius: 2
# min_neuropil_pixels
# min_neuropil_pixels: 350
# lam_percentile
# lam_percentile: 50.0
# allow_overlap
# allow_overlap: False
# use_builtin_classifier
# use_builtin_classifier: False
# classifier_path
# classifier_path:
# chan2_thres
# chan2_thres: 0.65
# baseline
# baseline: maximin
# win_baseline
# win_baseline: 60.0
# sig_baseline
# sig_baseline: 10.0
# prctile_baseline
# prctile_baseline: 8.0
# neucoeff
# neucoeff: 0.7
# {'data_path': ['/home/rum/Desktop/suite2pJed/run_suite2p']}

# %%
# print(os.getcwd())
# os.chdir('/home/rum/Desktop/suite2pJed/run_suite2p')
# save_folder = '/home/rum/Desktop/suite2pJed/run_suite2p' +os.sep+'test'
# print(save_folder)
# os.makedirs(save_folder, exist_ok=True)
# Out:
# /home/rum/Desktop/suite2pJed
# /home/rum/Desktop/suite2pJed/run_suite2p/test

# %%
output_ops = suite2p.run_s2p(ops=ops, db=db)
# Out:
# {'data_path': ['/home/rum/Desktop/suite2pJed/run_suite2p']}
# tif
# ** Found 1 tifs - converting to binary **
# time 0.55 sec. Wrote 120 frames per binary for 1 planes
# >>>>>>>>>>>>>>>>>>>>> PLANE 0 <<<<<<<<<<<<<<<<<<<<<<
# WARNING: number of frames is below 200, unpredictable behaviors may occur.
# NOTE: not registered / registration forced with ops['do_registration']>1
#       (no previous offsets to delete)
# NOTE: Applying builtin classifier at /home/rum/miniconda3/envs/suite2p/lib/python3.9/site-packages/suite2p/classifiers/classifier.npy
# ----------- REGISTRATION
# Reference frame, 16.21 sec.
# Registered 120/120 in 6.44s
# /home/rum/miniconda3/envs/suite2p/lib/python3.9/site-packages/suite2p/registration/register.py:50: RuntimeWarning: invalid value encountered in divide
#   dxy = dxy / dxy.mean()
# ----------- Total 34.10 sec
# ----------- ROI DETECTION
# Binning movie in chunks of length 10
# Binned movie of size [12,512,512] created in 0.10 sec.
# NOTE: estimated spatial scale ~6 pixels, time epochs 1.00, threshold 5.00
# 0 ROIs, score=12.64
# Detected 52 ROIs, 0.91 sec
# After removing overlaps, 52 ROIs remain
# ----------- Total 1.20 sec.
# ----------- EXTRACTION
# Masks created, 0.44 sec.
# /home/rum/miniconda3/envs/suite2p/lib/python3.9/site-packages/suite2p/extraction/extract.py:125: NumbaTypeSafetyWarning: unsafe cast from uint64 to int64. Precision may be lost.
#   Fi[n] = np.dot(data[:, cell_ipix[n]], cell_lam[n])
# Extracted fluorescence from 52 ROIs in 120 frames, 9.46 sec.
# ----------- Total 9.92 sec.
# ----------- CLASSIFICATION
# ['npix_norm', 'compact', 'skew']
# ----------- SPIKE DECONVOLUTION
# ----------- Total 0.00 sec.
# Plane 0 processed in 45.25 sec (can open in GUI).
# total = 45.82 sec.
# TOTAL RUNTIME 45.82 sec
